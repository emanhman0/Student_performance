# %%
#https://github.com/emanhman0/Student_performance

# %%
#Imports the pandas, matplotlib, and numpy library
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Reads in a student performance spreadsheet as a dataframe to look at data
df = pd.read_csv('student_performance_dataset.csv')

# %%
df
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 0             1    Male               4.0                98.0          6.5
# 1             2  Female               6.3               100.0          5.7
# 2             3    Male               4.9                85.3          7.9
# 3             4    Male               2.6                77.5          8.0
# 4             5    Male               2.2                89.6          4.6
# ..          ...     ...               ...                 ...          ...
# 995         996    Male               2.8                75.4          8.2
# 996         997    Male               6.7                88.4          7.1
# 997         998  Female               2.6                84.5          8.0
# 998         999  Female               4.6                85.3          8.1
# 999        1000    Male               3.9                77.4          6.1
#
#     parental_education internet_access extracurricular_activities  \
# ...

# %%
#Analysis questions in regards to the data
'''
Does sleeping and studying impact male and female students final grades?
Do male or female students study more on average?
How many hours of studying impacts a student's final grade?
Was there an increase in students from the Previous to Final grade?
'''
# Out:
# '\nDoes sleeping and studying impact male and female students final grades?\nDo male or female students study more on average?\nHow many hours of studying does a student with a poor Final Grade average?\nHow many hours should a student study to get a high Final Grade?\n'

# %%
#Dropping the parental_education column as I feel this does not impact any of my analysis questions
df2 = df.drop(columns=['parental_education'])

# %%
df2
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 0             1    Male               4.0                98.0          6.5
# 1             2  Female               6.3               100.0          5.7
# 2             3    Male               4.9                85.3          7.9
# 3             4    Male               2.6                77.5          8.0
# 4             5    Male               2.2                89.6          4.6
# ..          ...     ...               ...                 ...          ...
# 995         996    Male               2.8                75.4          8.2
# 996         997    Male               6.7                88.4          7.1
# 997         998  Female               2.6                84.5          8.0
# 998         999  Female               4.6                85.3          8.1
# 999        1000    Male               3.9                77.4          6.1
#
# ...

# %%
#Checks datatypes, to ensure there is no need to make any changes based off the data to be filtered
print(df2.dtypes)
# Out:
# student_id                      int64
# gender                         object
# study_time_hours              float64
# attendance_percent            float64
# sleep_hours                   float64
# internet_access                object
# extracurricular_activities     object
# part_time_job                  object
# previous_grade                float64
# final_exam_score              float64
# final_grade                    object
# dtype: object

# %%
#Compares the Males and Females based on their Study time, 'Do male or female students study more on average?'
plt.figure(figsize=(10,10))

plt.bar(df2.iloc[:, 1], df.iloc[:, 2])

plt.title('Male vs Female Average Study time')
plt.xlabel('Gender')
plt.ylabel('Study Time by Hour')
plt.legend(['Average Study Time'], loc = "upper right")

plt.show()

# %%
#Scatter Plot to showcase "How many hours of studying impacts a student's final grade?"
plt.figure(figsize=(10,10))

plt.scatter(df2.iloc[:, 2], df.iloc[:, 9])

plt.title('Studying vs Final Grade')
plt.xlabel('Study Time')
plt.ylabel('Grade')
#plt.legend(['Average Study Time'], loc = "upper right")

plt.show()

# %%
#Compares students previous grade to their Final Grade
labels = ['Previous Grade', 'Final Grade']

plt.boxplot([df2.iloc[:, 8], df2.iloc[:, 9]], labels=labels)

plt.show()
# Out:
# C:\Users\local_eharmon4\Temp\ipykernel_12020\904445040.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df2.iloc[:, 8], df2.iloc[:, 9]], labels=labels)

# %%
#Summary / Analysis on the data
'''
The graphs show the correlation between both Male and Female students and on average how much hours of sleep and studying
affect their grade. Overall, it appears the trend of data shows both Male and Female students have various different hours of study, resulting
in various different grades.

Female students get more average sleep than the Male students. 
Understanding the sleep schedule for students can help determine if there is any correlation between sleep, study time, and final grades.

The amount of time studied does not have any correlation to Final Grade, so long the students studied. There are cases where
some students can study for 1 hour and perform exceptionally with other students studying for longer hours such as 6 hours and receiving
a lower Final Grade. Looking at the data, it is recommended for students to have some type of study time due to Final Grades having an increase
to the Previous Grade.

In Conclusion, there is a nonlinear correlation between both female and male students sleeping and studying to get better grades.
However, there is an outlier with some students studying for an extended period of time and getting a worse grade, then a student
who studies less and gets a higher grade. The average student will need to study a significant amount to get better grades.
'''

'''
Within the results I failed to determine what type of students are in this dataset. This would be a great factor to help narrow which type of students
they are based off the data. I would like to gather this information next time I look at student data. I believe High School, Undergrad and Grad students
all may showcase different results.
'''
# Out:
# '\nWithin the results I failed to determine what type of students are in this dataset. This would be a great factor to help narrow which type of students\nthey are based off the data. I would like to gather this information next time I look at student data. I believe High School, Undergrad and Grad students\nall may showcase different results.\n'
